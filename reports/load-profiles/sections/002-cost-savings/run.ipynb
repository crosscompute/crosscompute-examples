# %%
from pandas import read_csv

# %%
t = read_csv('USA_SD_Rapid.City.Rgnl.AP.726620_TMY3_BASE.csv')

# %%
t.describe()
# Out:
#        Electricity:Facility [kW](Hourly)  Gas:Facility [kW](Hourly)  \
# count                        8760.000000                8760.000000
# mean                            1.054589                   4.700925
# std                             0.422886                   3.884396
# min                             0.430126                   0.233260
# 25%                             0.751052                   0.923674
# 50%                             0.942099                   4.064832
# 75%                             1.266521                   7.531345
# max                             2.556253                  18.786870
#
#        Heating:Electricity [kW](Hourly)  Heating:Gas [kW](Hourly)  \
# count                            8760.0               8760.000000
# mean                                0.0                  3.928175
# std                                 0.0                  3.821011
# min                                 0.0                  0.000000
# 25%                                 0.0                  0.000000
# 50%                                 0.0                  3.275207
# 75%                                 0.0                  6.704428
# max                                 0.0                 17.473894
#
#        Cooling:Electricity [kW](Hourly)  \
# count                       8760.000000
# mean                           0.023550
# std                            0.103671
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                            1.198938
#
#        HVACFan:Fans:Electricity [kW](Hourly)  Electricity:HVAC [kW](Hourly)  \
# count                            8760.000000                    8760.000000
# mean                                0.119842                       0.143393
# std                                 0.106377                       0.152917
# min                                 0.000000                       0.000000
# 25%                                 0.016167                       0.018850
# 50%                                 0.105739                       0.117139
# 75%                                 0.194517                       0.214252
# max                                 0.501513                       1.531985
#
#        Fans:Electricity [kW](Hourly)  \
# count                    8760.000000
# mean                        0.119842
# std                         0.106377
# min                         0.000000
# 25%                         0.016167
# 50%                         0.105739
# 75%                         0.194517
# max                         0.501513
#
#        General:InteriorLights:Electricity [kW](Hourly)  \
# count                                      8760.000000
# mean                                          0.205335
# std                                           0.196008
# min                                           0.049488
# 25%                                           0.065264
# 50%                                           0.114518
# 75%                                           0.292575
# max                                           0.835928
#
#        General:ExteriorLights:Electricity [kW](Hourly)  \
# count                                      8760.000000
# mean                                          0.044737
# std                                           0.042705
# min                                           0.010782
# 25%                                           0.014219
# 50%                                           0.024951
# 75%                                           0.063745
# max                                           0.182127
#
#        Appl:InteriorEquipment:Electricity [kW](Hourly)  \
# count                                      8760.000000
# mean                                          0.243630
# std                                           0.123567
# min                                           0.045929
# 25%                                           0.104490
# 50%                                           0.275875
# 75%                                           0.346769
# max                                           0.483984
#
#        Misc:InteriorEquipment:Electricity [kW](Hourly)  \
# count                                      8760.000000
# mean                                          0.398507
# std                                           0.104584
# min                                           0.269925
# 25%                                           0.315607
# 50%                                           0.363026
# 75%                                           0.483839
# max                                           0.684891
#
#        Water Heater:WaterSystems:Gas [kW](Hourly)
# count                                  8760.000000
# mean                                      0.745302
# std                                       0.314701
# min                                       0.214546
# 25%                                       0.510285
# 50%                                       0.757038
# 75%                                       0.974713
# max                                       1.542642

# %%
t.iloc[0]
# Out:
# Date/Time                                           01/01  01:00:00
# Electricity:Facility [kW](Hourly)                           1.09915
# Gas:Facility [kW](Hourly)                                   13.6075
# Heating:Electricity [kW](Hourly)                                  0
# Heating:Gas [kW](Hourly)                                    13.1546
# Cooling:Electricity [kW](Hourly)                                  0
# HVACFan:Fans:Electricity [kW](Hourly)                      0.378359
# Electricity:HVAC [kW](Hourly)                              0.378359
# Fans:Electricity [kW](Hourly)                              0.378359
# General:InteriorLights:Electricity [kW](Hourly)            0.161613
# General:ExteriorLights:Electricity [kW](Hourly)           0.0352113
# Appl:InteriorEquipment:Electricity [kW](Hourly)           0.0929429
# Misc:InteriorEquipment:Electricity [kW](Hourly)            0.413915
# Water Heater:WaterSystems:Gas [kW](Hourly)                 0.424425
# Name: 0, dtype: object

# %%
t[:3]
# Out:
#           Date/Time  Electricity:Facility [kW](Hourly)  \
# 0   01/01  01:00:00                           1.099152
# 1   01/01  02:00:00                           0.994697
# 2   01/01  03:00:00                           0.951204
#
#    Gas:Facility [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# 0                  13.607549                               0.0
# 1                  14.471545                               0.0
# 2                  14.709712                               0.0
#
#    Heating:Gas [kW](Hourly)  Cooling:Electricity [kW](Hourly)  \
# 0                 13.154615                               0.0
# 1                 14.113588                               0.0
# 2                 14.378051                               0.0
#
#    HVACFan:Fans:Electricity [kW](Hourly)  Electricity:HVAC [kW](Hourly)  \
# 0                               0.378359                       0.378359
# 1                               0.405479                       0.405479
# 2                               0.413068                       0.413068
#
#    Fans:Electricity [kW](Hourly)  \
# 0                       0.378359
# 1                       0.405479
# 2                       0.413068
#
#    General:InteriorLights:Electricity [kW](Hourly)  \
# 0                                         0.161613
# 1                                         0.094274
# 2                                         0.067339
#
#    General:ExteriorLights:Electricity [kW](Hourly)  \
# 0                                         0.035211
# 1                                         0.020540
# 2                                         0.014671
#
#    Appl:InteriorEquipment:Electricity [kW](Hourly)  \
# 0                                         0.092943
# 1                                         0.076186
# 2                                         0.062326
#
#    Misc:InteriorEquipment:Electricity [kW](Hourly)  \
# 0                                         0.413915
# 1                                         0.381106
# 2                                         0.376688
#
#    Water Heater:WaterSystems:Gas [kW](Hourly)
# 0                                     0.424425
# 1                                     0.331708
# 2                                     0.305716

# %%
len(t)
# Out:
# 8760

# %%
t[-3:]
# Out:
#              Date/Time  Electricity:Facility [kW](Hourly)  \
# 8757   12/31  22:00:00                           2.010565
# 8758   12/31  23:00:00                           1.691900
# 8759   12/31  24:00:00                           1.384056
#
#       Gas:Facility [kW](Hourly)  Heating:Electricity [kW](Hourly)  \
# 8757                  11.636562                               0.0
# 8758                  12.051300                               0.0
# 8759                  12.245711                               0.0
#
#       Heating:Gas [kW](Hourly)  Cooling:Electricity [kW](Hourly)  \
# 8757                 10.584009                               0.0
# 8758                 11.184703                               0.0
# 8759                 11.584534                               0.0
#
#       HVACFan:Fans:Electricity [kW](Hourly)  Electricity:HVAC [kW](Hourly)  \
# 8757                               0.304453                       0.304453
# 8758                               0.321794                       0.321794
# 8759                               0.333308                       0.333308
#
#       Fans:Electricity [kW](Hourly)  \
# 8757                       0.304453
# 8758                       0.321794
# 8759                       0.333308
#
#       General:InteriorLights:Electricity [kW](Hourly)  \
# 8757                                         0.599082
# 8758                                         0.445828
# 8759                                         0.313473
#
#       General:ExteriorLights:Electricity [kW](Hourly)  \
# 8757                                         0.130525
# 8758                                         0.097135
# 8759                                         0.068298
#
#       Appl:InteriorEquipment:Electricity [kW](Hourly)  \
# 8757                                         0.293949
# 8758                                         0.234174
# 8759                                         0.151456
#
#       Misc:InteriorEquipment:Electricity [kW](Hourly)  \
# 8757                                         0.665445
# 8758                                         0.575857
# 8759                                         0.500409
#
#       Water Heater:WaterSystems:Gas [kW](Hourly)
# 8757                                     1.006719
# 8758                                     0.826933
# 8759                                     0.626710

# %%
t.plot()

# %%
t[t.columns[0]][:3]
# Out:
# 0     01/01  01:00:00
# 1     01/01  02:00:00
# 2     01/01  03:00:00
# Name: Date/Time, dtype: object

# %%
t[t.columns[1]].plot()

# %%
t[t.columns[2]].plot()

# %%
t[t.columns[-1]].plot()

# %%
import pandas as pd
df = pd.DataFrame({
    'sales': [3, 2, 3, 9, 10, 6],
    'signups': [5, 5, 6, 12, 14, 13],
    'visits': [20, 42, 28, 62, 81, 50],
}, index=pd.date_range(start='2018/01/01', end='2018/07/01', freq='M'))
ax = df.plot.area()

# %%
ax = df.plot.area(stacked=False)
